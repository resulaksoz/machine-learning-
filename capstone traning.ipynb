# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
plt.rcParams["figure.figsize"] = (10,6)
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("dummy_scout_car.csv")
df
# Out:
#        Unnamed: 0  price  age            km  prev_owner     hp  \
# 0               0  15770  3.0  56013.000000         2.0   66.0
# 1               1  14500  2.0  80000.000000         1.0  141.0
# 2               2  14640  3.0  83450.000000         1.0   85.0
# 3               3  14500  3.0  73000.000000         1.0   66.0
# 4               4  16790  3.0  16200.000000         1.0   66.0
# ...           ...    ...  ...           ...         ...    ...
# 14371       14371  39950  0.0   1000.000000         1.0  165.0
# 14372       14372  39950  0.0   1601.473958         0.0  147.0
# 14373       14373  39885  0.0   9900.000000         1.0  165.0
# 14374       14374  39875  0.0     15.000000         1.0  146.0
# 14375       14375  40999  0.0   1601.473958         1.0  165.0
#
#        Consumption_comb  Nr. of Doors  Nr. of Seats  Displacement  ...  \
# 0                   3.8           5.0           5.0        1422.0  ...
# 1                   5.6           3.0           4.0        1798.0  ...
# 2                   3.8           4.0           4.0        1598.0  ...
# 3                   3.8           3.0           4.0        1422.0  ...
# 4                   4.0           5.0           5.0        1422.0  ...
# ...                 ...           ...           ...           ...  ...
# 14371               6.8           5.0           7.0        1798.0  ...
# 14372               5.3           5.0           5.0        1997.0  ...
# 14373               7.4           5.0           5.0        1798.0  ...
# 14374               5.3           5.0           7.0        1997.0  ...
# 14375               6.8           5.0           5.0        1798.0  ...
#
#        Upholstery_color_Grey  Upholstery_color_Orange  Upholstery_color_Other  \
# 0                          0                        0                       0
# 1                          1                        0                       0
# 2                          0                        0                       0
# 3                          0                        0                       0
# 4                          0                        0                       0
# ...                      ...                      ...                     ...
# 14371                      0                        0                       0
# 14372                      0                        0                       0
# 14373                      0                        0                       0
# 14374                      0                        0                       0
# 14375                      0                        0                       0
#
#        Upholstery_color_Red  Upholstery_color_White  Upholstery_color_Yellow  \
# 0                         0                       0                        0
# 1                         0                       0                        0
# 2                         0                       0                        0
# 3                         0                       0                        0
# 4                         0                       0                        0
# ...                     ...                     ...                      ...
# 14371                     0                       0                        0
# 14372                     0                       0                        0
# 14373                     0                       0                        0
# 14374                     0                       0                        0
# 14375                     0                       0                        0
#
#        vat_VAT deductible  vat_VAT undeductible  Drive chain_front  \
# 0                       1                     0                  1
# 1                       0                     0                  1
# 2                       1                     0                  1
# 3                       0                     1                  1
# 4                       0                     1                  1
# ...                   ...                   ...                ...
# 14371                   1                     0                  1
# 14372                   1                     0                  1
# 14373                   1                     0                  1
# 14374                   1                     0                  1
# 14375                   1                     0                  0
#
#        Drive chain_rear
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 14371                 0
# 14372                 0
# 14373                 0
# 14374                 0
# 14375                 0
#
# [14376 rows x 226 columns]

# %%
df=df.iloc[1:3000]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'price', 'age', 'km', 'prev_owner', 'hp',
#        'Consumption_comb', 'Nr. of Doors', 'Nr. of Seats', 'Displacement',
#        ...
#        'Upholstery_color_Grey', 'Upholstery_color_Orange',
#        'Upholstery_color_Other', 'Upholstery_color_Red',
#        'Upholstery_color_White', 'Upholstery_color_Yellow',
#        'vat_VAT deductible', 'vat_VAT undeductible', 'Drive chain_front',
#        'Drive chain_rear'],
#       dtype='object', length=226)

# %%
x=df.drop(columns='price')

# %%
y=df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state =42)

# %%
print("Train features shape : ", x_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", x_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (2399, 225)
# Train target shape   :  (2399,)
# Test features shape  :  (600, 225)
# Test target shape    :  (600,)

# %%
x_train
# Out:
#       Unnamed: 0  age            km  prev_owner     hp  Consumption_comb  \
# 1570        1570  1.0    6892.00000         1.0  141.0               5.6
# 2230        2230  0.0     100.00000         1.0   85.0               4.8
# 2297        2297  0.0    3000.00000         1.0   70.0               4.3
# 1801        1801  0.0    1705.42568         0.0   85.0               4.8
# 1274        1274  1.0   12500.00000         1.0   60.0               4.4
# ...          ...  ...           ...         ...    ...               ...
# 1639        1639  1.0   25900.00000         1.0   66.0               3.9
# 1096        1096  1.0   21937.00000         1.0   66.0               4.0
# 1131        1131  1.0    9900.00000         1.0   70.0               4.3
# 1295        1295  2.0   24265.00000         1.0   60.0               4.2
# 861          861  2.0  100800.00000         1.0   60.0               4.2
#
#       Nr. of Doors  Nr. of Seats  Displacement  Cylinders  ...  \
# 1570           5.0           5.0        1798.0        3.0  ...
# 2230           5.0           5.0        1395.0        3.0  ...
# 2297           5.0           5.0        1395.0        3.0  ...
# 1801           5.0           4.0        1395.0        3.0  ...
# 1274           5.0           4.0        1395.0        3.0  ...
# ...            ...           ...           ...        ...  ...
# 1639           5.0           5.0        1422.0        3.0  ...
# 1096           5.0           4.0        1422.0        3.0  ...
# 1131           5.0           5.0        1395.0        3.0  ...
# 1295           5.0           4.0        1395.0        3.0  ...
# 861            5.0           4.0        1395.0        3.0  ...
#
#       Upholstery_color_Grey  Upholstery_color_Orange  Upholstery_color_Other  \
# 1570                      1                        0                       0
# 2230                      0                        0                       1
# 2297                      0                        0                       0
# 1801                      0                        0                       0
# 1274                      0                        0                       0
# ...                     ...                      ...                     ...
# 1639                      0                        0                       0
# 1096                      0                        0                       0
# 1131                      0                        0                       0
# 1295                      0                        0                       0
# 861                       0                        0                       0
#
#       Upholstery_color_Red  Upholstery_color_White  Upholstery_color_Yellow  \
# 1570                     0                       0                        0
# 2230                     0                       0                        0
# 2297                     0                       0                        0
# 1801                     0                       0                        0
# 1274                     0                       0                        0
# ...                    ...                     ...                      ...
# 1639                     0                       0                        0
# 1096                     0                       0                        0
# 1131                     0                       0                        0
# 1295                     0                       0                        0
# 861                      0                       0                        0
#
#       vat_VAT deductible  vat_VAT undeductible  Drive chain_front  \
# 1570                   1                     0                  1
# 2230                   1                     0                  1
# 2297                   1                     0                  1
# 1801                   1                     0                  1
# 1274                   0                     1                  1
# ...                  ...                   ...                ...
# 1639                   1                     0                  1
# 1096                   1                     0                  1
# 1131                   1                     0                  1
# 1295                   0                     1                  1
# 861                    0                     1                  1
#
#       Drive chain_rear
# 1570                 0
# 2230                 0
# 2297                 0
# 1801                 0
# 1274                 0
# ...                ...
# 1639                 0
# 1096                 0
# 1131                 0
# 1295                 0
# 861                  0
#
# [2399 rows x 225 columns]

# %%
x_test
# Out:
#       Unnamed: 0  age       km  prev_owner    hp  Consumption_comb  \
# 1377        1377  1.0  22100.0         1.0  66.0               3.9
# 933          933  1.0  10600.0         1.0  85.0               3.7
# 145          145  3.0  13960.0         1.0  66.0               3.9
# 1753        1753  1.0   9916.0         1.0  60.0               4.2
# 52            52  3.0  27600.0         1.0  70.0               4.2
# ...          ...  ...      ...         ...   ...               ...
# 638          638  2.0  21200.0         1.0  70.0               4.2
# 696          696  3.0  46000.0         1.0  66.0               3.7
# 227          227  3.0  66000.0         1.0  85.0               3.7
# 2604        2604  3.0  67405.0         1.0  81.0               4.8
# 1104        1104  2.0  15200.0         1.0  85.0               3.7
#
#       Nr. of Doors  Nr. of Seats  Displacement  Cylinders  ...  \
# 1377           5.0           5.0        1422.0        3.0  ...
# 933            5.0           4.0        1598.0        4.0  ...
# 145            4.0           5.0        1422.0        4.0  ...
# 1753           4.0           5.0        1395.0        3.0  ...
# 52             5.0           4.0        1395.0        3.0  ...
# ...            ...           ...           ...        ...  ...
# 638            4.0           5.0        1395.0        3.0  ...
# 696            5.0           4.0        1422.0        3.0  ...
# 227            5.0           5.0        1598.0        4.0  ...
# 2604           4.0           5.0        1197.0        4.0  ...
# 1104           5.0           5.0        1598.0        4.0  ...
#
#       Upholstery_color_Grey  Upholstery_color_Orange  Upholstery_color_Other  \
# 1377                      0                        0                       0
# 933                       0                        0                       1
# 145                       0                        0                       0
# 1753                      0                        0                       0
# 52                        0                        0                       0
# ...                     ...                      ...                     ...
# 638                       0                        0                       0
# 696                       0                        0                       0
# 227                       1                        0                       0
# 2604                      0                        0                       0
# 1104                      0                        0                       0
#
#       Upholstery_color_Red  Upholstery_color_White  Upholstery_color_Yellow  \
# 1377                     0                       0                        0
# 933                      0                       0                        0
# 145                      0                       0                        0
# 1753                     0                       0                        0
# 52                       0                       0                        0
# ...                    ...                     ...                      ...
# 638                      0                       0                        0
# 696                      0                       0                        0
# 227                      0                       0                        0
# 2604                     0                       0                        0
# 1104                     0                       0                        0
#
#       vat_VAT deductible  vat_VAT undeductible  Drive chain_front  \
# 1377                   1                     0                  1
# 933                    1                     0                  1
# 145                    1                     0                  1
# 1753                   1                     0                  1
# 52                     0                     1                  1
# ...                  ...                   ...                ...
# 638                    1                     0                  1
# 696                    0                     1                  1
# 227                    0                     1                  1
# 2604                   1                     0                  1
# 1104                   1                     0                  1
#
#       Drive chain_rear
# 1377                 0
# 933                  0
# 145                  0
# 1753                 0
# 52                   0
# ...                ...
# 638                  0
# 696                  0
# 227                  0
# 2604                 0
# 1104                 0
#
# [600 rows x 225 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([16804.02675892, 20404.57397043, 16561.08854897, 17106.2990855 ,
#        12181.85631011, 12730.51258021, 22436.53586059, 19028.60932967,
#        16732.26555964, 17874.83963206, 25857.10233804, 13535.10156617,
#        12777.36586319, 18276.03046449, 19989.69826114, 13496.96271762,
#        21378.23045661, 14122.67242045, 21574.13068561, 21825.88563285,
#        22059.30734074, 14594.90824631, 17924.75558832, 25845.49615725,
#        10734.61770203, 22583.38839163, 16525.03081988, 17765.80646792,
#         2.09922973e+03,  1.07053986e+02, -1.16587272e+03,  4.77484718e-12,
#        -4.91876740e+02,  5.91171556e-12, -3.51537142e+02,  2.30853394e+02,
#        -2.36257711e+02,  3.41060513e-13, -8.23493812e+02, -8.44560873e+00,
#        -3.39307112e+02, -7.66167182e+02, -5.68434189e-13,  2.22755148e-12,
#         2.68517045e+03,  1.90252845e+03, -2.57419289e+03,  8.06001820e+01,
#        -2.85640905e+02, -9.66474968e+00,  1.33963496e+03, -2.72848411e-12,
#        -3.24498369e+02, -1.71328427e+02, -7.34145536e+01, -9.09494702e-13,
#         3.04662823e+02,  2.86680316e+02,  2.25468317e+02, -2.17899956e+02,
#        -1.68067146e+02, -6.91909314e+02, -1.49202303e+02,  6.62127230e+01,
#         1.49358582e+02,  6.42834857e+02, -4.51125793e+01, -2.27373675e-13,
#        -4.73857843e+02,  1.81898940e-12,  4.53190670e+02, -3.97704401e+02,
#         5.99237654e+02, -1.13748394e+02, -1.78815597e+03, -3.02648936e+01,
#         2.84217094e-14,  3.89706326e+01,  9.65251683e+02,  3.43832543e+03,
#        -3.63547995e+03,  6.82121026e-13, -1.13686838e-13,  2.27373675e-13,
#         0.00000000e+00, -2.16004992e-12, -1.70530257e-13, -4.07455991e+03,
#        -3.02193209e+02,  3.43832543e+03,  4.81269604e+02, -2.93835104e+02,
#        -3.62794363e+02,  0.00000000e+00,  1.70133274e+03, -1.50279307e+02,
#         7.14970814e+02, -8.73902024e+02, -2.22194701e+02,  5.10222630e+02,
#         8.30502767e+02, -2.39666981e+02, -3.77546096e+02, -3.91263327e+02,
#        -1.25560416e+03, -3.99254913e+02,  0.00000000e+00, -4.98399865e+02,
#        -2.45646492e+02, -1.14773739e+04, -3.44667702e+02, -4.59476096e+02,
#         2.81861738e+03, -4.15233318e+02,  9.99138419e+02, -3.29959296e+03,
#         1.92666535e+03,  2.93557490e+02, -4.22362980e+02,  5.23278433e+02,
#        -1.12255978e+03,  3.21785251e+01, -4.44969871e+00, -9.46219207e+01,
#        -4.38004441e+03,  5.63485188e+01,  0.00000000e+00,  8.82404757e+01,
#         1.27677566e+03,  1.18039453e+01,  9.55572240e+02,  2.09037518e+03,
#         0.00000000e+00,  2.70215008e+02,  9.26201885e+01, -1.93765880e+01,
#         0.00000000e+00])

# %%
model.intercept_
# Out:
# 14664.671578090107

# %%
my_dict = {"Actual": y_test, "Pred": y_pred, "Residual":y_test-y_pred}

# %%
pd.DataFrame(my_dict)
# Out:
#       Actual          Pred     Residual
# 1377   16390  16804.026759  -414.026759
# 933    20500  20404.573970    95.426030
# 145    17990  16561.088549  1428.911451
# 1753   16889  17106.299086  -217.299086
# 52     11450  12181.856310  -731.856310
# ...      ...           ...          ...
# 638    13990  13765.732922   224.267078
# 696    14000  13955.930468    44.069532
# 227    16500  16146.208905   353.791095
# 2604   16760  17273.504803  -513.504803
# 1104   15900  15750.490400   149.509600
#
# [600 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9045919343855509

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 967.5058168377345

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 1681299.708838373

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 1296.649416318217

# %%
def eval_metric(actual, pred):
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    rmse = np.sqrt(mean_squared_error(actual, pred))
    R2_score = r2_score(actual, pred)
    print("Model testing performance:")
    print("--------------------------")
    print(f"R2_score \t: {R2_score}")
    print(f"MAE \t\t: {mae}")
    print(f"MSE \t\t: {mse}")
    print(f"RMSE \t\t: {rmse}")

# %%
eval_metric(y_test, y_pred)
# Out:
# Model testing performance:
# --------------------------
# R2_score 	: 0.9045919343855509
# MAE 		: 967.5058168377345
# MSE 		: 1681299.708838373
# RMSE 		: 1296.649416318217

# %%
residuals = y_test-y_pred

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = y_test, y = residuals) #-residuals
plt.axhline(y = 0, color ="r", linestyle = "--")
plt.ylabel("residuals")
plt.show()

# %%
sns.kdeplot(residuals)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
stats.probplot(residuals, dist ="norm", plot =plt);

# %%
from scipy.stats import skew
skew(residuals)
# Out:
# -0.07714975856818636

# %%
from yellowbrick.regressor import ResidualsPlot

# Instantiate the linear model and visualizer
model = LinearRegression()
visualizer = ResidualsPlot(model)

visualizer.fit(x_train, y_train)  # Fit the training data to the visualizer
visualizer.score(x_test, y_test)  # Evaluate the model on the test data
visualizer.show();        # Finalize and render the figure

# %%
from yellowbrick.regressor import PredictionError
# Instantiate the linear model and visualizer
model = LinearRegression()
visualizer = PredictionError(model)

visualizer.fit(x_train, y_train)  # Fit the training data to the visualizer
visualizer.score(x_test, y_test)  # Evaluate the model on the test data
visualizer.show();

# %%
df
# Out:
#       Unnamed: 0  price  age       km  prev_owner     hp  Consumption_comb  \
# 1              1  14500  2.0  80000.0         1.0  141.0               5.6
# 2              2  14640  3.0  83450.0         1.0   85.0               3.8
# 3              3  14500  3.0  73000.0         1.0   66.0               3.8
# 4              4  16790  3.0  16200.0         1.0   66.0               4.0
# 5              5  15090  3.0  63668.0         1.0   85.0               3.5
# ...          ...    ...  ...      ...         ...    ...               ...
# 2995        2995  24500  1.0  20000.0         1.0  110.0               4.4
# 2996        2996  28300  3.0  58444.0         1.0  110.0               4.4
# 2997        2997  28300  1.0  16000.0         1.0  110.0               4.3
# 2998        2998  27900  1.0     15.0         1.0   85.0               3.9
# 2999        2999  28000  1.0     41.0         1.0   85.0               3.9
#
#       Nr. of Doors  Nr. of Seats  Displacement  ...  Upholstery_color_Grey  \
# 1              3.0           4.0        1798.0  ...                      1
# 2              4.0           4.0        1598.0  ...                      0
# 3              3.0           4.0        1422.0  ...                      0
# 4              5.0           5.0        1422.0  ...                      0
# 5              4.0           5.0        1598.0  ...                      0
# ...            ...           ...           ...  ...                    ...
# 2995           5.0           5.0        1968.0  ...                      0
# 2996           5.0           5.0        1968.0  ...                      0
# 2997           4.0           5.0        1968.0  ...                      0
# 2998           5.0           5.0        1598.0  ...                      0
# 2999           5.0           5.0        1598.0  ...                      0
#
#       Upholstery_color_Orange  Upholstery_color_Other  Upholstery_color_Red  \
# 1                           0                       0                     0
# 2                           0                       0                     0
# 3                           0                       0                     0
# 4                           0                       0                     0
# 5                           0                       0                     0
# ...                       ...                     ...                   ...
# 2995                        0                       0                     0
# 2996                        0                       0                     0
# 2997                        0                       0                     0
# 2998                        0                       0                     0
# 2999                        0                       0                     0
#
#       Upholstery_color_White  Upholstery_color_Yellow  vat_VAT deductible  \
# 1                          0                        0                   0
# 2                          0                        0                   1
# 3                          0                        0                   0
# 4                          0                        0                   0
# 5                          0                        0                   0
# ...                      ...                      ...                 ...
# 2995                       0                        0                   1
# 2996                       0                        0                   0
# 2997                       0                        0                   1
# 2998                       0                        0                   1
# 2999                       0                        0                   0
#
#       vat_VAT undeductible  Drive chain_front  Drive chain_rear
# 1                        0                  1                 0
# 2                        0                  1                 0
# 3                        1                  1                 0
# 4                        1                  1                 0
# 5                        1                  1                 0
# ...                    ...                ...               ...
# 2995                     0                  1                 0
# 2996                     1                  1                 0
# 2997                     0                  1                 0
# 2998                     0                  1                 0
# 2999                     1                  1                 0
#
# [2999 rows x 226 columns]

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
X = df.drop("price", axis =1)
y = df.price

# %%
polynomial_converter = PolynomialFeatures(degree =2, include_bias =False)

# %%
polynomial_converter.fit(X)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
poly_trans=polynomial_converter.transform(X)

# %%
poly_trans.shape
# Out:
# (2999, 25650)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(poly_trans, y, test_size = 0.3, random_state = 101)

# %%
from sklearn.linear_model import LinearRegression

# %%
model_poly = LinearRegression()

# %%
model_poly.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model_poly.predict(X_test)

# %%
my_dict = {"Actual": y_test, "pred": y_pred, "residual": y_test-y_pred}
compare = pd.DataFrame(my_dict)
compare.head(20)
# Out:
#       Actual          pred      residual
# 2396   13000 -3.418484e+05  3.548484e+05
# 1625   16980 -3.216531e+05  3.386331e+05
# 1460   23400 -8.372747e+05  8.606747e+05
# 1768   24706 -9.936518e+04  1.240712e+05
# 458    13000  5.191216e+05 -5.061216e+05
# 509    13360  9.485666e+04 -8.149666e+04
# 423    13900  1.252396e+07 -1.251006e+07
# 19     18500  4.549454e+05 -4.364454e+05
# 587    12890 -1.576118e+06  1.589008e+06
# 971    19900  8.786950e+04 -6.796950e+04
# 1910   26740  3.174863e+05 -2.907463e+05
# 1092   15000 -2.638346e+06  2.653346e+06
# 258    17890 -6.175916e+04  7.964916e+04
# 2735   14999  5.802657e+05 -5.652667e+05
# 1029   19640 -1.283097e+06  1.302737e+06
# 2492   17950 -2.446237e+06  2.464187e+06
# 424    13900 -8.773765e+05  8.912765e+05
# 2813   14980  2.883584e+06 -2.868604e+06
# 1380   16445 -1.434759e+06  1.451204e+06
# 2074   21490 -4.049778e+04  6.198778e+04

# %%
def eval_metric(actual, pred):
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    rmse = np.sqrt(mean_squared_error(actual, pred))
    R2_score = r2_score(actual, pred)
    print("Model performance:")
    print("--------------------------")
    print(f"R2_score \t: {R2_score}")
    print(f"MAE \t\t: {mae}")
    print(f"MSE \t\t: {mse}")
    print(f"RMSE \t\t: {rmse}")

# %%
eval_metric(y_test, y_pred)
# Out:
# Model performance:
# --------------------------
# R2_score 	: -825956.1958811411
# MAE 		: 1457006.3896407653
# MSE 		: 15670131376971.018
# RMSE 		: 3958551.676683155
